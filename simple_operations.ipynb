# %% [markdown]
# <a href="https://colab.research.google.com/github/yunusemreoglu/PYTHON-DERS-NOTLARI/blob/main/simple_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
######### Simple operations#########
'''
******Arithmetic operators in python*****

+ = addition

- = subtraction

* = multiplication

/ = float division

** = exponentiation

// = floor division

% = modulus

----------------------------------------------------------------------


***********işlem önceliği******* ;


1 - parentheses : ()
2 - power : **
3 - unary minus : -3 (ÖNCE EKSİ OLAN RAKAMI İŞLEME SOKAR)
4 - multiplication and division : *, /
5 - addition and subtraction : +, -


---------------------------------------------------------------------

print.__doc__ 'ta default olarak sep ' ' bir boşluk olarak gelir.


sep = ' ' "ne verirsek onu uygular. \n\n çift enter.

end = '\n' " sonraki satıra geç demek. ## İÇİNE NE KOYARSAN O. "-" YAPARSAN YANYANA - KOYAR..

print('i', end=' ')
print('will say', end=' ')
print("'i missed you'", end=' ')
print('to my mother') 

i will say 'i missed you' to my mother



print('smoking', 'is', 'slowly', 'killing me', sep=' + ')

smoking + is + slowly + killing me


--------------------------------------------------------------


-= değişkeni yerinde azaltır,
+= değişkeni yerinde artırın,
*= değişkeni yerinde çarpın,
/= değişkeni yerinde bölmek,
//= ﬂ o veya değişkeni yerinde böl,
%= yerinde değişkenin modülünü döndürür,
**= sayının üssünü alır.

---------------------------------------------------------------

****** \ ****** ters sılaş sihirli bir karakter. sağdaki  değeri değiştirebilyor.....

------------------------------------------------------------------

************ESCAPE SEQUENCES*************


\n : yeni satır anlamına gelir,

\t: tabişaret anlamına gelir ,

\b: backspace anlamına gelir. İmleci bir karakter sola hareket ettirir.

---------------------------
ÖRNEK
print('C:\\november\number_expenditure.txt')  #### BAŞTAKİ \ 'IN BİRİNİ ÇIKARMAK
                                              İSTİYORSAN BİR TANE DAHA \ KOY!!
C:\november
umber_expenditure.txt
--------------------
ÖRNEK
print('C:\november\number_expenditure.txt')
C:
ovember
umber_expenditure.txt
--------------
ÖRNEK
print("one", "two", "three", sep="\t")

one     two     three
-------------------------
ÖRNEK
print('we', '\bare', '\bunited')

weareunited
-------------------------

İSTİSNA

print('it\'s funny to learn Python')    ## NORMALDE TEK TIRNAK İÇERİSİNDE TEK
                                        TIRNAK OLMAZ AMA TERS SILAŞ BU KURTARIYO..
                                        yani ters sılaş \ ' ın özelliğini kaybettiriyor..
                                
it's funny to learn Python

--------------------------------------------------------------------------------------------


*************Boolean Operations******************

What is a boolean in Python?

Boolean is one of the built-in data types in Python, it mainly contains
two values, and they are True and False.(Boole, Python'daki yerleşik veri
türlerinden biridir, esas olarak iki değer içerir ve bunlar Doğru ve Yanlış'dır.)

not, and, or = Python'daki 3 yerleşik boole operatörü.. (işlem önceliğide bu.)

not = işlemi ters döndürür.

and = işlemde hepsi True ise sondaki ni verir.     "olmazsa olmazlar and ile kullanılır"
      1 tane bile false varsa ilkini verir.

or = işlemin hepsi False ise sondakini verir.       " bir tane bile true varsa kafi
                                                      yani birisi bile yeter dersen or operatörü"                                                  
     1 tane bile True varsa ilkini verir.              


----------------------------------

*****Python'un kendi boolean veri türü olmasına rağmen, mantıksal işlemlerde
 genellikle boole olmayan değerleri kullanırız.

 - turthy
 - falsy

***** 
## None.                                                 falsy değer sonuç False
## Herhangi bir sayısal türden sıfır: 0, 0.0, 0j         falsy     //
## Boş diziler ve koleksiyonlar: '', [], {}.             falsy     //
bir değer olarak değerlendirilir.                        turthy..değer sonuç True


-------------------------------------------------------------

kadayıf örneği..

satırın sonuna sadece \ koyarsan bir alt satırdan devam eder. hata vermez.

'''

# %% [markdown]
# <a href="https://colab.research.google.com/github/yunusemreoglu/PYTHON-DERS-NOTLARI/blob/main/Collection_types_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##############"""""""Dictionaries"""""""""###############
'''

S: Python'da sözlük nedir?
A: Python sözlüğü, Python'da desteklenen veri türlerinden biridir. 
Sırasız bir eleman koleksiyonudur. Sözlüklerdeki öğeler, anahtar / değer
çiftleri olarak saklanır. Sözlükler anahtarlara göre dizine alınır.
Örneğin, aşağıda my_dict adında bir diktemiz var. İki anahtar, 
meyve ve sebzenin yanı sıra karşılık gelen değerleri, muz ve soğan içerir.

my_dict = {'meyve': 'muz', 'sebzeli': 'soğan'}



{key:value1, key2:value2}


Buradaki value olanlara herşey gelebilir ama keylere herşey gelmiyor.
Key ' dekiler sınırlı. Bool, str, tuple , int ..kullanılabiliyor.
--------------------------------------------------------------------------------

Creating a dict:
-------------
{}
dict()

first_dict = {1 : "one", "two" : 2, False : [1,2,3], 1.5 : ("one", "two"), (1,2) : "yunus"}
first_dict

--------------------------------------------------------------------------------

second_dict = {[1,2] : "yunus"}                     # key list olmadı.
second_dict

--------------------------------------------------------------------------------

sas = {{1 : "bir"} : "one", "two": 2}
sas                                                 # key {} ' de olmuyor..
--------------------------------------------------------------------------------

dict() fonk. değişken değer atama öantığı gibi düşün:

xx = dict(bir = "one", iki = "two")
xx
{'bir': 'one', 'iki': 'two'}

------------------
yy = dict(1 = "one", 2 = "two")
yy                                                # Bir üstteki örnekle karşılaştır ve...
SyntaxError: keyword can't be an expression        değişken atama kuralları aklına gelsin!

------------------------------------

--------------------------------------------------------------------------------
İndexleme:
-----------
Bir öğeye erişim sözdizimi çok basittir. Erişmek istediğimiz anahtarı köşeli
parantez içinde yazıyoruz. Bu yöntem hem bir dikteye öğe eklemek hem de oradan okumak için çalışır.

Aşağıdaki örneklerde, bir dikte oluşturmamıza ve ona bir anahtar / değer 
çifti eklememize olanak tanıyan birkaç yöntem göreceksiniz:


örnek1:

state_capitals = {'Arkansas': 'Little Rock',
                  'Colorado': 'Denver',
                  'California': 'Sacramento',
                  'Georgia': 'Atlanta' 
                 }

print(type(state_capitals['Colorado'])) # accessing method
<class 'str'>

(döndüreceği değer tipi neyse o. Dikkat et.)

--------------------------------------------------------------------------------

sehir = "ist"
sehir1 = "ank"
nüfus = 1000

sehirler = {1 :sehir, 2 : sehir1, "nüfusum": nüfus}
sehirler
{1: 'ist', 2: 'ank', 'nüfusum': 1000}

sehirler['nüfusum']
1000 ( int ).

--------------------------------------------------------------------------------
Yeni değer atama:

state_capitals = {'Arkansas': 'Little Rock',
'Colorado': 'Denver',
'California': 'Sacramento',
'Georgia': 'Atlanta'}
state_capitals['Virginia'] = 'Richmond' # adding a new item                      
print(state_capitals)

{'Arkansas': 'Little Rock', 'Colorado': 'Denver', 'California': 'Sacramento', 'Georgia': 'Atlanta', 'Virginia': 'Richmond'}

--------------------------------------------------------------------------------

state_capitals["California"] = "istanbul"        # californiayı değiştirdik..
state_capitals 

{'Arkansas': 'Little Rock',                      #mevcut bi valueyi değiştirdik.
 'California': 'istanbul',
 'Colorado': 'Denver',
 'Georgia': 'Atlanta',
 'Virginia': 'Richmond'}

--------------------------------------------------------------------------------

mix_values = {'animal': ('dog', 'cat'),  # tuple type
              'planet': ['Neptun', 'Saturn', 'Jupiter'],  # list type
              'number': 40,  # int type
              'pi': 3.14,  # float type
              'is_good': True}  # bool type

mix_keys = {22 : "integer",
            1.2 : "float",
            True : "boolean",
            "key" : "string"}
--------------------------------------------------------------------------------

x = "yunus"
y = "emre"                               # dic oluşturduk..
z = "ali"

family = dict(name1 = x, name2 = y, name3 = z)
family

{'name1': 'yunus', 'name2': 'emre', 'name3': 'ali'}

----------------------or--------------------------------------------------------

family3 = {
    'name1': "yunus",
    'name2': "eeee",
    'name' : "üüüü"
}
print(family3)

{'name1': 'yunus', 'name2': 'eeee', 'name': 'üüüü'}
--------------------------------------------------------------------------------

dict_by_dict = dict(animal='dog', planet='neptun', number=40, pi=3.14, is_good=True)

print(dict_by_dict)          # dict oluşturuyoruz (=) 'e dikkat et aynı değişken 
                                atıyormuş gibi.ve sonuç tipi neyse o dönüyor unutma..!!

{'animal': 'dog', 'planet': 'neptun', 'number': 40, 'pi': 3.14, 'is_good': True}

--------------------------------------------------------------------------------
--------------------------------------------------------------------------------
Main Operations with Dictionaries (Sözlüklerle Ana İşlemler)

.items()
.keys()
.values()  methodları.  bunların çıktılarını iyi incele.

örnek:


dict_by_dict = {'animal': 'dog',
                'planet': 'neptun',                           # main operations with dicts..
                'number': 40,
                'pi': 3.14,                                   # çıktılarını iyi incele.
                'is_good': True}

print(dict_by_dict.items(), '\n')
print(dict_by_dict.keys(), '\n')
print(dict_by_dict.values())


dict_items([('animal', 'dog'), ('planet', 'neptun'), ('number', 40), ('pi', 3.14), ('is_good', True)]) 
(her item bir tuple olarak döndü dikkat et.)

dict_keys(['animal', 'planet', 'number', 'pi', 'is_good']) 
(key'ler bir liste olarak döndü.)

dict_values(['dog', 'neptun', 40, 3.14, True])
(value'lerde bir liste olarak döndü.)

--------------------------------------------------------------------------------

dict_by_dict = {'animal': 'dog',
                'planet': 'neptun',                           # main operations with dicts..
                'number': 40,
                'pi': 3.14,                                   # çıktılarını iyi incele.
                'is_good': True}

print(list(dict_by_dict.items()), '\n')
print(list(dict_by_dict.keys()), '\n')
print(list(dict_by_dict.values()))

[('animal', 'dog'), ('planet', 'neptun'), ('number', 40), ('pi', 3.14), ('is_good', True)] 

['animal', 'planet', 'number', 'pi', 'is_good'] 

['dog', 'neptun', 40, 3.14, True]


Bir üstteki örnekle karşılaştır. (list)

--------------------------------------------------------------------------------


.uptade() methodu.            #sonuna bir (sözlük yapısı formatında) eleman ekledi.
                              birden fazla elemanı aynı anda ekleyebiliyoruz bu methodla.
                              mevcut olanıda değiştirebiliyoruz.

dict_by_dict = {'animal': 'dog',
                'planet': 'neptun',
                'number': 40,
                'pi': 3.14,
                'is_good': True}

dict_by_sict.update({'is_bad' : False})
print(dict_by_dict)

{'animal': 'dog',
'planet': 'neptun',
'number': 40,
'pi': 3.14,
'is_good': True,
'is_bad': False}
--------------------------------------------------------------------------------

del fonksiyonu:
syntax:
del dictionary_name['key']

dict_by_dict = {'animal': 'dog',
               'planet': 'neptun',
               'number': 40,
               'pi': 3.14,
               'is_good': True,
               'is_bad': False}

del dict_by_dict['animal']

print(dict_by_dict) 

{'planet': 'neptun',
'number': 40,
'pi': 3.14,
'is_good': True,
'is_bad': False}

--------------------------------------------------------------------------------
family = dict(name1='ben', name2='emir', name3="han", name4="joseph")
family.update({"name5": "ayse", "name6": "tylor", "name1" : "Adana"})
print(family)
del family["name5"]
print(family)

{'name1': 'Adana', 'name2': 'emir', 'name3': 'han', 'name4': 'joseph', 'name5': 'ayse', 'name6': 'tylor'}
{'name1': 'Adana', 'name2': 'emir', 'name3': 'han', 'name4': 'joseph', 'name6': 'tylor'}


--------------------------------------------------------------------------------

****** sözlüklerde aynı satırda birden fazla öğeyi silme:
        del family["name5"], family["name1"]

--------------------------------------------------------------------------------


in ve not in operatörü:     (tüm collectionlarda kullanılır.)
----------------------

İn operatörünü kullandığımızda; anahtar sözlükte ise, sonuç Doğru,
aksi takdirde Yanlış olacaktır.

Not in kullandığımızda; anahtar sözlükte değilse, sonuç Doğru, aksi 
takdirde Yanlış olacaktır.

dict_by_dict = {'planet': 'neptun',
               'number': 40,
               'pi': 3.14,
               'is_good': True,
               'is_bad': False}

print('pi' in dict_by_dict) 
print('animal' not in dict_by_dict)  # remember, we have deleted 'animal'

True
True  
--------------------------------------------------------------------------------

dict_by_dict = {'planet': 'neptun',
               'number': 40,
               'pi': 3.14,
               'is_good': True,
               'is_bad': False}                 bu şekildede olur.


print(3.14 in dict_by_dict.values())
print(True in dict_by_dict.values())
print("pi" in dict_by_dict.keys())

True
True 
True
--------------------------------------------------------------------------------

Nested dictionaries:

school_records={
    "personal_info":
        {"kid":{"tom": {"class": "intermediate", "age": 10},
                "sue": {"class": "elementary", "age": 8}
               },
         "teen":{"joseph":{"class": "college", "age": 19},
                 "marry":{"class": "high school", "age": 16}
               },               
        },
        
    "grades_info":
        {"kid":{"tom": {"math": 88, "speech": 69},
                "sue": {"math": 90, "speech": 81}
               },
         "teen":{"joseph":{"coding": 80, "math": 89},
                 "marry":{"coding": 70, "math": 96}
               },               
        },        
}

print(len(school_records))
2
--------------------------------------------------------------------------------
school_records={
    "personal_info":
        {"kid":{"tom": {"class":"intermediate", "age":10},
                "sue": {"class":"elementary", "age":8}
               },
         "teen":{"joseph":{"class":"college", "age":19},
                 "marry":{"class":"high school", "age":16}
               },               
        },
}

print(school_records['personal_info']['teen']['marry']['age'])   ### accessing işlemi.
                                                                 #iç içe sözlük üzerinde izdekslemeye devam

16
--------------------------------------------------------------------------------
print(list(school_records["grades_info"]["teen"]["joseph"].items()))

[('coding', 80), ('math', 89)]
--------------------------------------------------------------------------------

print(school_records["grades_info"]["teen"]["joseph"].items())
dict_items([('coding', 80), ('math', 89)])

bir üstteki örnekle karşılaştır.

--------------------------------------------------------------------------------

friends = {
    "friend1" : {"first" : "yunus", "last" : "emre" },
    "friend2" : { "first" : "eee", "last" : "s"},  
    "friend3" : {"first" : "sdf" , "last" : "fsad"}}
print(friends)

{'friend1': {'first': 'yunus', 'last': 'emre'}, 'friend2': {'first': 'eee', 'last': 's'}, 'friend3': {'first': 'sdf', 'last': 'fsad'}}

--------------------------------------------------------------------------------
favourite = {
    "friends": {
      "friend1": {"first": "Su", "last": "Bold"},
      "friend2": {"first": "Steve", "last": "Smith"},
      "friend3": {"first": "Sergio", "last": "Tatoo"}},
    

    "family" : {
        "family1": {"first": "Joseph", "last": "Forest"},
        "family2": {"first": "Mariam", "last": "Forest"},
        "family3": {"first": "Johanna", "last": "Forest"},
    }
    
}
favourite


{'family': {'family1': {'first': 'Joseph', 'last': 'Forest'},
  'family2': {'first': 'Mariam', 'last': 'Forest'},
  'family3': {'first': 'Johanna', 'last': 'Forest'}},
 'friends': {'friend1': {'first': 'Su', 'last': 'Bold'},
  'friend2': {'first': 'Steve', 'last': 'Smith'},
  'friend3': {'first': 'Sergio', 'last': 'Tatoo'}}}



____________________________________________________________________________end.
































'''

# %%
dict_by_dict = {'planet': 'neptun',
               'number': 40,
               'pi': 3.14,
               'is_good': True,
               'is_bad': False}


print(3.14 in dict_by_dict.values())
print(True in dict_by_dict.values())
print("pi" in dict_by_dict.keys())
# Out:
# True
# True
# True

# %%
family = dict(name1='ben', name2='emir', name3="han", name4="joseph")
family.update({"name5": "ayse", "name6": "tylor", "name1" : "Adana"})
print(family)
del family["name5"], family["name1"]
print(family)
# Out:
# {'name1': 'Adana', 'name2': 'emir', 'name3': 'han', 'name4': 'joseph', 'name5': 'ayse', 'name6': 'tylor'}
# {'name2': 'emir', 'name3': 'han', 'name4': 'joseph', 'name6': 'tylor'}

# %%
state_capitals = {'Arkansas': 'Little Rock',
                  'Colorado': 'Denver',
                  'California': 'Sacramento',
                  'Georgia': 'Atlanta' 
                 }

print(type(state_capitals['Colorado'])) # accessing method
# Out:
# <class 'str'>

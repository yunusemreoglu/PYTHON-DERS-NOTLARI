# %% [markdown]
# <a href="https://colab.research.google.com/github/yunusemreoglu/PYTHON-DERS-NOTLARI/blob/main/The_Strength_of_Strings_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#######################The Strength of Strings in Python######################

'''
*****************Indexing&Slicing Strings**************************

string[:] : returns the full copy of the sequence

string[start:] : returns elements from start to the end element

string[:stop] : returns element from the 1st element to stop-1

string[::step] : returns each element with a given step


fruit = 'Orange'

print('Word                   : ' , fruit)
print('First letter           : ' , fruit[0])
print('Second letter          : ' , fruit[1])
print("3rd to 5th letters     : " , fruit[2:5])
print("Letter all after 3rd   : " , fruit[2:])


Word                   :  Orange
First letter           :  O
Second letter          :  r
3rd to 5th letters     :  ang
Letter all after 3rd   :  ange

-----------------------------------------------------------------------------

**********String Formatting with Arithmetic Syntax*********

1- Arithmetic syntax (+, *, and =),

2- % operator formatting,

3- string.format() method,

4- f-string formatting.
--------------------------------------

"+" "*" "="   --->

+ = ifadeleri birbşrşle birleştirir. 

* = arka arkaya birleştirir. sağına soluna koyman farketmiyor. 
 print(*'yunus') ' la karıştırma. bu elemanlarını ayırır.
  sağına koyarsa birşey yapmaz.
--------------------------------------------------------------------------------

**************String Formatting with 'string.format()' Method*****************

########    'string {} string {} string'.format(data1, data2) 
                                    (0)     (1)
----------

######## print('{state} is the most {adjective} state of the {country}'.\
 format(state='California', country='USA', adjective='crowded'))  

 burada bi sıra söz konusu değil. içersinde keyword argümanlar tanımlanmış.
----------
####### dışarıda da değerleri yazabiliriz o zaman sırayla koyar.

state='California'
country='USA'
adjective='crowded'

print('{} is the most {} state of the {}'.\
 format(state, country, adjective))   
-----------
######## index numaralrını kullanarak da yapabilirsin
print('{0} is the most {2} state of the {1}'.\
 format(state, country, adjective))  


 print("{6} {0} {5} {3} {4} {1} {2}".\
 format('have', 6, 'months', 'a job', 'in', 'found', 'I will')) 
-----------------

###############******* At this point, let us give you some explanations :
 Positional arguments are arguments that can be 
 called by their position in the function or method definition.
  Keyword arguments are arguments that can 
  be called by their names.************#################

  (Konumsal argümanlar , işlev veya yöntem tanımındaki konumlarıyla 
  çağrılabilen argümanlardır. Anahtar kelime argümanları
   isimleriyle çağrılabilen argümanlardır.)

print('{0} is the most {adjective} state of the {country}'.\
format('California', country='USA', adjective='crowded'))

keyword = atanalar.  
positional = soldan sağa sırayla..  

****NOT =Positional (her zaman önce) olanlar keywordlardan önce gelir.****

positionallar sırayla gelir soldan sağa..

print("{}-{}-{x}-{}".format("a", "c", "d" x = "b"))

unutma !! positionallar keywordlardan önce gelir, sonra positionallar index numa
larnına göre sıralanabilirler...



condition = "circumstances"
morality = "generosity"

phrase = '{} {} {} {}'.format('in all','wins')
print(phrase)   

bu soruyu anlamlı bir cümle olacak şekilde yaz..


phrase = '{morality} {1} {0} {condition}'.format('in all','wins', condition = "circumstances",
morality = "generosity") 1.yol..


phrase = '{morality} {1} {0} {condition}'.format('wins', 'in all', condition = "circumstances",
morality = "generosity") 2.yol..

-----------------------------------

dışarıda atadığın değerleri sırasıyla alıyor.. bunu unutma..!!!




-----------------------------------------------------------------------------

#####******String Formatting with 'f-string'******######


---f"string {variable1} string {variable2} string"

--     sample = f"{2 ** *}

    print(sample)  8  içerisinde işlemde yapabiliyoruz..

--    my_name = 'JOSEPH'
      output = f"My name is {my_name.capitalize()}"

      print(output)

--      name = "Joseph"
        job = "teachers"
        domain = "Data Science"
        message = (
             f"Hi {name}. "
             f"You are one of the {job} "
             f"in the {domain} section."
        )
print(message)        b   BU PARANTAZLİ HALİ.. EĞER PARANTEZLİ İSTEMİYORSAN!!

**********PRİNT'İ KULLANMAYI UNUTMA!!!!!!!


name = "Joseph"
job = "teachers"
domain = "Data Science"
message = f"Hi {name}. " \                   BUDA PARANTEZ OLMADAN KULLANILMSI!!
     f"You are one of the {job} " \
     f"in the {domain} section."

print(message)

------------------------------------------------------------------------


#####**** Main String Operations *** #####

Immutability = Değiştirilemez.. stringler.. değiştireceksen yeni bir değişkene 
                            atayacaksın..

--------------------------------------
############      Searching a String      #############

What are the string.startswith() and string.endswith() method used for? Describe how?

To search patterns in a string there are two useful methods called startswith()
and endswith() that search for the particular pattern in the immediate beginning
or end of a string and return True if the expression is found.

(((((((((((string.startswith()ve string.endswith()yöntemi ne için kullanılıyor? Nasıl olduğunu açıklayın?

iki faydalı denilen yöntem vardır bir dizede desenleri aramak için startswith()ve 
endswith()bir dize ve getiri derhal başında veya sonunda özellikle desen için arama 
Trueifadesi bulunursa. ))))))))))

string.startswith()
                         ARADIĞI PATENTİ BULURSA SONUCU True yada False olarak dödürür.
string.endswith()      



text = 'www.google.com'
print(text.endswith('.com'))     true
print(text.startswith('http:'))  true

---------------------------------------------------

string.startswith(prefix[, start[, end]])
string.endswith(suffix[, start[, end]])       buradaki [] 'ler opsiyonel..

örnek:

email = "yunusemre@yunusemre.com is my e-mail address"

print(email.startswith("@", 9))    9. indexten başla demek. @ bulduysa sonuç True yani @ ' la başlıyor demek.
print(email.endswith("-", 10, 32)) 10.ibdex ile 31 indexleri arasını ara. sondan başla 31. karakter - ise sonuç true.


------------------------------------------------------------------------

#########*****Changing a String******##########

string.method(arguments)  oop 'den geliyor..


***str.replace(old, new[, count]) herhangi bir stringin içindeki old ve new i ....(count) defa çevirir.
                                                          sıradan .....(count) kere çevirir.
                                                          eğer (-1) verirsen hepsini çevirir.

** str.swapcase() büyük harfleri küçüğe.. Küçüğü büyüğe..

** str.capitalize() ilk harfi büyüğe çevirir.

** str.upper() hepsini büyüğe

** str.lower() hepsini küçüğe..

** str.title() ilk harfleri büyüğe.. diğerleri küçüğe..

<<<<<----unutma stringlerin immutable olduğunu unutma...---->>>>>


--------------------------------

*** string.method1().method2().method3()... = her methodun sonunda yeni bir string gelir ve 
                                          sırasıyla methodlar uygulanır..
örnek:

sentence = "I live and work in Virginia"

print(sentence.upper())  

print(sentence.lower())

print(sentence.swapcase())

print(sentence)

I LIVE AND WORK IN VIRGINIA
i live and work in virginia
i LIVE AND WORK IN vIRGINIA
I live and work in Virginia
-----------------------------------------
örnek:

sentence = "I live and work in Virginia"
title_sentence = sentence.title() 
print(title_sentence)  

changed_sentence = sentence.replace("i", "+")
print(changed_sentence)  

print(sentence)

I Live And Work In Virginia
I l+ve and work +n V+rg+n+a
I live and work in Virginia
-------------------------------------------
print("Actions speaks louder than words".upper().swapcase().capitalize()), will this code work? 
If yes, what the output will be? Describe how?

Yes it works. The syntax is : string.method(). Changing the string using these methods returns
string type again. The output is :
Actions speaks louder than words
-----------------------------------------

test = 's0d0me and g0m0re'
test = test.replace("0", "o" -1)   (-1 default olarak geldi.  3 yazsan ilk 3 ünü çevirir.)
print(test)  
Sodome and Gomore..


---------------------------------------------------------------------------

################******Editing a String*****#####################
                    ( değiştirmek- düzenlemek)
                    
string.method(arguments)

string.strip() : str nin sağında ve solundaki boşlıkları atar. parametre verirsen sağda ve solda onlarıda atar.
string.rstrip() : str nin sağındaki boşluğu at . parametre verirsen sağdakini atar.
string.left() :  // // //  solundaki // // // ., //              //  soldakini //.

örnekler:
------------------------
space_string = "     listen first      "
print(space_string.strip()) 
listen first
---------------------------

source_string = "interoperability"
print(source_string.strip("yi"))     [başta ve sonda i ve y ' yi gördüğüsürece atar.]
nteroperabilit                         içerisine bir tane değer atayabiliyoruz..
-------------------------------


text = ' kjsdhf klsdfsdf sdf in pre-classz'
print(text.strip("sz").upper())

KJSDHF KLSDFSDF SDF IN PRE-CLA

--------------------------------------

text = 'In Gog wee Trust'                     e nin birinden kurtul ve w yi büyült

print(text.replace("wee", "we").title())
print(text.title().replace("ee", "e"))

------------------------------------------------------------



**************ders sonundaki string ile ilgili ekstralar....******************

# \\ çıktı almak için ne yapılmalı ?

print("\\\\")
print("\\" + "\\" )

------------------------

a = 3
b = 4 
print("{} + {}' ün toplamı {} 'dir.".format(a, b ,a+b))

---------------------
text = "{}, {}, {}".format (3.1463, 5.367, 7.3214856)

**{:} kullanırsam sonuçlar değişiyor..

**{:.2f} dersen . dan sonra 2 basamağını veririr.(ondalık kısmını)..

**{:.2}  dersen baştan 2 tanesini verir..
----------
text = "{:.2s} - {:.3s} - {:.4s}".format("3.1463", "5.367", "7.3214856")

**{:.4s} dersen str nin 4 tanesini al.. örnek : 7.321

----------------

textlerin sağa sola ortaya yaslama....
örnek:
text = "{:}".format("yunus")

{:>10} dersen 10 karakterlik bi alanda sağa yaslar.
'     yunus'
-----
örnek:
text1 = 'formatlama {:>10} formatlama'.format("test")    test i 10 karakterlik bi alanda sağa yasla..
text1
'formatlama       test formatlama'      
-------------------------------
örnek:
{:<10} dersen 10 karakterlik bi alanda sola yaslar.
'yunus     '
--------------
örnek:
text2 = '{:<10} formatlama'.format("test")  10 birimlik bi alanda test i sola yasla
text2
'test       formatlama'
----------------
örnek:

"{:^20}".format("test")      test i 20 karakterlik bi alanda ortala..
'        test        '

-------
text1 = 'formatlama {:^20} formatlama'.format("test")
'formatlama         test         formatlama'
---------------
örnek:
"{:.5}".format("hippopotamus")     5 tane karakterini al..
'hippo'
---------------
örnek:
"{:10.3}".format("hippopotamus")     10 birimlik bi alanda 3 tane karakter al..
'hip       '
------
örnek:
"{:>10.3}".format("hippopotamus")     10 karakterlik bi alanda 3 karakter al ve sağa yasla..
  '       hip'

-------
örnek:
"{:.5}".format("3.14668686")                  5 tane karakter al...

'3.146'


'''
